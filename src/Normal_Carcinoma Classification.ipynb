# %%
import torch
from torchvision import datasets, transforms as T
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
import torch.nn.functional as F

from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import cv2
from sklearn.model_selection import train_test_split

# %%
import random
import numpy as np
import os
import cv2
import glob
from PIL import Image
import PIL.ImageOps    

#다음 변수를 수정하여 새로 만들 이미지 갯수를 정합니다.
num_augmented_images = 120

file_path = '../data_augmented_new/train/0/'
save_path = '../data_augmented_new/train/0/'
file_names = os.listdir(file_path)
total_origin_image_num = len(file_names)
augment_cnt = 1

for i in range(1, num_augmented_images):
    change_picture_index = random.randrange(1, total_origin_image_num-1)
    print(change_picture_index)
    print(file_names[change_picture_index])
    file_name = file_names[change_picture_index]
    
    origin_image_path = '../data_augmented_new/train/0/' + file_name
    print(origin_image_path)
    image = Image.open(origin_image_path)
    random_augment = random.randrange(1,4)
    
    if(random_augment == 1):
        #이미지 좌우 반전
        print("invert")
        inverted_image = image.transpose(Image.FLIP_LEFT_RIGHT)
        inverted_image.save(save_path + 'inverted_' + str(augment_cnt) + '.png')
    
    elif (random_augment == 2):
        #이미지 기울이기
        print("rotate")
        rotated_image = image.rotate(random.randrange(-20, 20))
        rotated_image.save(save_path + 'rotated_' + str(augment_cnt) + '.png')        
    augment_cnt += 1
# Out:
# 43
# 0 (49).jpg
# ../data_augmented_new/train/0/0 (49).jpg
# invert
# 112
# noiseAdded_15.png
# ../data_augmented_new/train/0/noiseAdded_15.png
# invert
# 51
# 0 (56).jpg
# ../data_augmented_new/train/0/0 (56).jpg
# rotate
# 134
# noiseAdded_65.png
# ../data_augmented_new/train/0/noiseAdded_65.png
# rotate
# 110
# noiseAdded_118.png
# ../data_augmented_new/train/0/noiseAdded_118.png
# rotate
# 222
# rotated_3.png
# ../data_augmented_new/train/0/rotated_3.png
# invert
# 163
# N_514_정-3.jpg
# ../data_augmented_new/train/0/N_514_정-3.jpg
# 81
# inverted_31.png
# ../data_augmented_new/train/0/inverted_31.png
# rotate
# 100
# inverted_81.png
# ../data_augmented_new/train/0/inverted_81.png
# invert
# 42
# 0 (48).jpg
# ../data_augmented_new/train/0/0 (48).jpg
# rotate
# 156
# N_459_ISSAYEV-2.jpg
# ../data_augmented_new/train/0/N_459_ISSAYEV-2.jpg
# invert
# 199
# N_862_강-2.jpg
# ../data_augmented_new/train/0/N_862_강-2.jpg
# 215
# rotated_117.png
# ../data_augmented_new/train/0/rotated_117.png
# rotate
# 74
# inverted_16.png
# ../data_augmented_new/train/0/inverted_16.png
# rotate
# 16
# 0 (24).jpg
# ../data_augmented_new/train/0/0 (24).jpg
# rotate
# 14
# 0 (22).jpg
# ../data_augmented_new/train/0/0 (22).jpg
# 177
# N_782_백-7.jpg
# ../data_augmented_new/train/0/N_782_백-7.jpg
# 49
# 0 (54).jpg
# ../data_augmented_new/train/0/0 (54).jpg
# rotate
# 234
# rotated_63.png
# ../data_augmented_new/train/0/rotated_63.png
# invert
# 183
# N_823_정-11.jpg
# ../data_augmented_new/train/0/N_823_정-11.jpg
# invert
# 197
# N_846_우-1.jpg
# ../data_augmented_new/train/0/N_846_우-1.jpg
# invert
# 41
# 0 (47).jpg
# ../data_augmented_new/train/0/0 (47).jpg
# 41
# 0 (47).jpg
# ../data_augmented_new/train/0/0 (47).jpg
# rotate
# 52
# 0 (57).jpg
# ../data_augmented_new/train/0/0 (57).jpg
# rotate
# 148
# N_043_신-1.jpg
# ../data_augmented_new/train/0/N_043_신-1.jpg
# rotate
# 131
# noiseAdded_60.png
# ../data_augmented_new/train/0/noiseAdded_60.png
# 79
# inverted_28.png
# ../data_augmented_new/train/0/inverted_28.png
# invert
# 164
# N_514_정-4.jpg
# ../data_augmented_new/train/0/N_514_정-4.jpg
# rotate
# 86
# inverted_43.png
# ../data_augmented_new/train/0/inverted_43.png
# 187
# N_823_정-15.jpg
# ../data_augmented_new/train/0/N_823_정-15.jpg
# rotate
# 96
# inverted_72.png
# ../data_augmented_new/train/0/inverted_72.png
# 15
# 0 (23).jpg
# ../data_augmented_new/train/0/0 (23).jpg
# invert
# 66
# inverted_108.png
# ../data_augmented_new/train/0/inverted_108.png
# 7
# 0 (16).jpg
# ../data_augmented_new/train/0/0 (16).jpg
# invert
# 137
# noiseAdded_78.png
# ../data_augmented_new/train/0/noiseAdded_78.png
# 190
# N_823_정-4.jpg
# ../data_augmented_new/train/0/N_823_정-4.jpg
# 58
# 0 (7).jpg
# ../data_augmented_new/train/0/0 (7).jpg
# 221
# rotated_23.png
# ../data_augmented_new/train/0/rotated_23.png
# 238
# rotated_71.png
# ../data_augmented_new/train/0/rotated_71.png
# rotate
# 72
# inverted_119.png
# ../data_augmented_new/train/0/inverted_119.png
# invert
# 157
# N_476_신-1.jpg
# ../data_augmented_new/train/0/N_476_신-1.jpg
# rotate
# 230
# rotated_51.png
# ../data_augmented_new/train/0/rotated_51.png
# 123
# noiseAdded_42.png
# ../data_augmented_new/train/0/noiseAdded_42.png
# rotate
# 50
# 0 (55).jpg
# ../data_augmented_new/train/0/0 (55).jpg
# invert
# 151
# N_195_이-2.jpg
# ../data_augmented_new/train/0/N_195_이-2.jpg
# 48
# 0 (53).jpg
# ../data_augmented_new/train/0/0 (53).jpg
# invert
# 201
# N_890_박-2.jpg
# ../data_augmented_new/train/0/N_890_박-2.jpg
# 87
# inverted_45.png
# ../data_augmented_new/train/0/inverted_45.png
# invert
# 83
# inverted_34.png
# ../data_augmented_new/train/0/inverted_34.png
# invert
# 149
# N_043_신-2.jpg
# ../data_augmented_new/train/0/N_043_신-2.jpg
# rotate
# 179
# N_782_백-9.jpg
# ../data_augmented_new/train/0/N_782_백-9.jpg
# rotate
# 87
# inverted_45.png
# ../data_augmented_new/train/0/inverted_45.png
# invert
# 221
# rotated_23.png
# ../data_augmented_new/train/0/rotated_23.png
# invert
# 51
# 0 (56).jpg
# ../data_augmented_new/train/0/0 (56).jpg
# rotate
# 129
# noiseAdded_59.png
# ../data_augmented_new/train/0/noiseAdded_59.png
# invert
# 65
# inverted_103.png
# ../data_augmented_new/train/0/inverted_103.png
# 21
# 0 (29).jpg
# ../data_augmented_new/train/0/0 (29).jpg
# rotate
# 68
# inverted_111.png
# ../data_augmented_new/train/0/inverted_111.png
# rotate
# 108
# noiseAdded_107.png
# ../data_augmented_new/train/0/noiseAdded_107.png
# 74
# inverted_16.png
# ../data_augmented_new/train/0/inverted_16.png
# 86
# inverted_43.png
# ../data_augmented_new/train/0/inverted_43.png
# invert
# 196
# N_834_김-1.jpg
# ../data_augmented_new/train/0/N_834_김-1.jpg
# 74
# inverted_16.png
# ../data_augmented_new/train/0/inverted_16.png
# rotate
# 236
# rotated_66.png
# ../data_augmented_new/train/0/rotated_66.png
# 207
# rotated_100.png
# ../data_augmented_new/train/0/rotated_100.png
# 21
# 0 (29).jpg
# ../data_augmented_new/train/0/0 (29).jpg
# invert
# 93
# inverted_68.png
# ../data_augmented_new/train/0/inverted_68.png
# invert
# 29
# 0 (36).jpg
# ../data_augmented_new/train/0/0 (36).jpg
# 214
# rotated_114.png
# ../data_augmented_new/train/0/rotated_114.png
# rotate
# 44
# 0 (5).jpg
# ../data_augmented_new/train/0/0 (5).jpg
# 38
# 0 (44).jpg
# ../data_augmented_new/train/0/0 (44).jpg
# 223
# rotated_32.png
# ../data_augmented_new/train/0/rotated_32.png
# 133
# noiseAdded_62.png
# ../data_augmented_new/train/0/noiseAdded_62.png
# rotate
# 17
# 0 (25).jpg
# ../data_augmented_new/train/0/0 (25).jpg
# invert
# 177
# N_782_백-7.jpg
# ../data_augmented_new/train/0/N_782_백-7.jpg
# invert
# 30
# 0 (37).jpg
# ../data_augmented_new/train/0/0 (37).jpg
# invert
# 77
# inverted_21.png
# ../data_augmented_new/train/0/inverted_21.png
# 155
# N_459_ISSAYEV-1.jpg
# ../data_augmented_new/train/0/N_459_ISSAYEV-1.jpg
# 49
# 0 (54).jpg
# ../data_augmented_new/train/0/0 (54).jpg
# rotate
# 124
# noiseAdded_46.png
# ../data_augmented_new/train/0/noiseAdded_46.png
# 139
# noiseAdded_80.png
# ../data_augmented_new/train/0/noiseAdded_80.png
# 193
# N_823_정-7.jpg
# ../data_augmented_new/train/0/N_823_정-7.jpg
# rotate
# 224
# rotated_40.png
# ../data_augmented_new/train/0/rotated_40.png
# invert
# 13
# 0 (21).jpg
# ../data_augmented_new/train/0/0 (21).jpg
# 38
# 0 (44).jpg
# ../data_augmented_new/train/0/0 (44).jpg
# 228
# rotated_49.png
# ../data_augmented_new/train/0/rotated_49.png
# rotate
# 74
# inverted_16.png
# ../data_augmented_new/train/0/inverted_16.png
# rotate
# 220
# rotated_22.png
# ../data_augmented_new/train/0/rotated_22.png
# rotate
# 54
# 0 (59).jpg
# ../data_augmented_new/train/0/0 (59).jpg
# invert
# 101
# inverted_82.png
# ../data_augmented_new/train/0/inverted_82.png
# 24
# 0 (31).jpg
# ../data_augmented_new/train/0/0 (31).jpg
# rotate
# 83
# inverted_34.png
# ../data_augmented_new/train/0/inverted_34.png
# rotate
# 177
# N_782_백-7.jpg
# ../data_augmented_new/train/0/N_782_백-7.jpg
# 101
# inverted_82.png
# ../data_augmented_new/train/0/inverted_82.png
# invert
# 207
# rotated_100.png
# ../data_augmented_new/train/0/rotated_100.png
# rotate
# 59
# 0 (8).jpg
# ../data_augmented_new/train/0/0 (8).jpg
# rotate
# 77
# inverted_21.png
# ../data_augmented_new/train/0/inverted_21.png
# invert
# 220
# rotated_22.png
# ../data_augmented_new/train/0/rotated_22.png
# 187
# N_823_정-15.jpg
# ../data_augmented_new/train/0/N_823_정-15.jpg
# 146
# noiseAdded_98.png
# ../data_augmented_new/train/0/noiseAdded_98.png
# rotate
# 226
# rotated_44.png
# ../data_augmented_new/train/0/rotated_44.png
# 122
# noiseAdded_4.png
# ../data_augmented_new/train/0/noiseAdded_4.png
# invert
# 111
# noiseAdded_14.png
# ../data_augmented_new/train/0/noiseAdded_14.png
# rotate
# 195
# N_823_정-9.jpg
# ../data_augmented_new/train/0/N_823_정-9.jpg
# invert
# 108
# noiseAdded_107.png
# ../data_augmented_new/train/0/noiseAdded_107.png
# invert
# 145
# noiseAdded_97.png
# ../data_augmented_new/train/0/noiseAdded_97.png
# 207
# rotated_100.png
# ../data_augmented_new/train/0/rotated_100.png
# rotate
# 64
# inverted_102.png
# ../data_augmented_new/train/0/inverted_102.png
# rotate
# 229
# rotated_50.png
# ../data_augmented_new/train/0/rotated_50.png
# invert
# 154
# N_301_고-2.jpg
# ../data_augmented_new/train/0/N_301_고-2.jpg
# invert
# 173
# N_782_백-3.jpg
# ../data_augmented_new/train/0/N_782_백-3.jpg
# rotate
# 140
# noiseAdded_84.png
# ../data_augmented_new/train/0/noiseAdded_84.png
# rotate
# 61
# inverted_1.png
# ../data_augmented_new/train/0/inverted_1.png
# invert
# 232
# rotated_56.png
# ../data_augmented_new/train/0/rotated_56.png
# invert
# 126
# noiseAdded_5.png
# ../data_augmented_new/train/0/noiseAdded_5.png
# invert
# 96
# inverted_72.png
# ../data_augmented_new/train/0/inverted_72.png
# invert
# 92
# inverted_67.png
# ../data_augmented_new/train/0/inverted_67.png
# 169
# N_732_이-2.jpg
# ../data_augmented_new/train/0/N_732_이-2.jpg
# invert
# 99
# inverted_76.png
# ../data_augmented_new/train/0/inverted_76.png
# rotate

# %%
num_augmented_images = 120

file_path = '../data_augmented_new/train/1/'
save_path = '../data_augmented_new/train/1/'
file_names = os.listdir(file_path)
total_origin_image_num = len(file_names)
augment_cnt = 1

for i in range(1, num_augmented_images):
    change_picture_index = random.randrange(1, total_origin_image_num-1)
    print(change_picture_index)
    print(file_names[change_picture_index])
    file_name = file_names[change_picture_index]
    
    origin_image_path = '../data_augmented_new/train/1/' + file_name
    print(origin_image_path)
    image = Image.open(origin_image_path)
    random_augment = random.randrange(1,4)
    
    if(random_augment == 1):
        #이미지 좌우 반전
        print("invert")
        inverted_image = image.transpose(Image.FLIP_LEFT_RIGHT)
        inverted_image.save(save_path + 'inverted_' + str(augment_cnt) + '.png')
    
    elif (random_augment == 2):
        #이미지 기울이기
        print("rotate")
        rotated_image = image.rotate(random.randrange(-20, 20))
        rotated_image.save(save_path + 'rotated_' + str(augment_cnt) + '.png')        
    augment_cnt += 1
# Out:
# 135
# inverted_60.png
# ../data_augmented_new/train/1/inverted_60.png
# invert
# 223
# rotated_15.png
# ../data_augmented_new/train/1/rotated_15.png
# invert
# 180
# noiseAdded_24.png
# ../data_augmented_new/train/1/noiseAdded_24.png
# invert
# 213
# rotated_1.png
# ../data_augmented_new/train/1/rotated_1.png
# invert
# 116
# inverted_36.png
# ../data_augmented_new/train/1/inverted_36.png
# rotate
# 204
# noiseAdded_80.png
# ../data_augmented_new/train/1/noiseAdded_80.png
# invert
# 181
# noiseAdded_25.png
# ../data_augmented_new/train/1/noiseAdded_25.png
# invert
# 233
# rotated_45.png
# ../data_augmented_new/train/1/rotated_45.png
# invert
# 81
# C_823_정-1.jpg
# ../data_augmented_new/train/1/C_823_정-1.jpg
# rotate
# 240
# rotated_61.png
# ../data_augmented_new/train/1/rotated_61.png
# invert
# 216
# rotated_105.png
# ../data_augmented_new/train/1/rotated_105.png
# rotate
# 203
# noiseAdded_8.png
# ../data_augmented_new/train/1/noiseAdded_8.png
# 101
# inverted_15.png
# ../data_augmented_new/train/1/inverted_15.png
# rotate
# 213
# rotated_1.png
# ../data_augmented_new/train/1/rotated_1.png
# 87
# C_823_정-6.jpg
# ../data_augmented_new/train/1/C_823_정-6.jpg
# invert
# 55
# C_721_신-19.jpg
# ../data_augmented_new/train/1/C_721_신-19.jpg
# invert
# 211
# noiseAdded_92.png
# ../data_augmented_new/train/1/noiseAdded_92.png
# 82
# C_823_정-10.jpg
# ../data_augmented_new/train/1/C_823_정-10.jpg
# rotate
# 1
# abnormal (10).jpg
# ../data_augmented_new/train/1/abnormal (10).jpg
# rotate
# 45
# C_721_신-1.jpg
# ../data_augmented_new/train/1/C_721_신-1.jpg
# invert
# 98
# inverted_11.png
# ../data_augmented_new/train/1/inverted_11.png
# rotate
# 215
# rotated_104.png
# ../data_augmented_new/train/1/rotated_104.png
# rotate
# 19
# C_253_다-11.jpg
# ../data_augmented_new/train/1/C_253_다-11.jpg
# 7
# abnormal (5).jpg
# ../data_augmented_new/train/1/abnormal (5).jpg
# invert
# 161
# inverted_92.png
# ../data_augmented_new/train/1/inverted_92.png
# rotate
# 143
# inverted_68.png
# ../data_augmented_new/train/1/inverted_68.png
# rotate
# 149
# inverted_76.png
# ../data_augmented_new/train/1/inverted_76.png
# invert
# 67
# C_721_신-3.jpg
# ../data_augmented_new/train/1/C_721_신-3.jpg
# invert
# 108
# inverted_24.png
# ../data_augmented_new/train/1/inverted_24.png
# invert
# 245
# rotated_76.png
# ../data_augmented_new/train/1/rotated_76.png
# invert
# 7
# abnormal (5).jpg
# ../data_augmented_new/train/1/abnormal (5).jpg
# rotate
# 41
# C_568_변-2.jpg
# ../data_augmented_new/train/1/C_568_변-2.jpg
# rotate
# 50
# C_721_신-14.jpg
# ../data_augmented_new/train/1/C_721_신-14.jpg
# invert
# 70
# C_721_신-6.jpg
# ../data_augmented_new/train/1/C_721_신-6.jpg
# 196
# noiseAdded_59.png
# ../data_augmented_new/train/1/noiseAdded_59.png
# invert
# 102
# inverted_16.png
# ../data_augmented_new/train/1/inverted_16.png
# rotate
# 140
# inverted_65.png
# ../data_augmented_new/train/1/inverted_65.png
# invert
# 16
# C_224_조-5.jpg
# ../data_augmented_new/train/1/C_224_조-5.jpg
# invert
# 194
# noiseAdded_56.png
# ../data_augmented_new/train/1/noiseAdded_56.png
# rotate
# 252
# rotated_93.png
# ../data_augmented_new/train/1/rotated_93.png
# rotate
# 122
# inverted_43.png
# ../data_augmented_new/train/1/inverted_43.png
# 48
# C_721_신-12.jpg
# ../data_augmented_new/train/1/C_721_신-12.jpg
# invert
# 45
# C_721_신-1.jpg
# ../data_augmented_new/train/1/C_721_신-1.jpg
# 103
# inverted_18.png
# ../data_augmented_new/train/1/inverted_18.png
# rotate
# 82
# C_823_정-10.jpg
# ../data_augmented_new/train/1/C_823_정-10.jpg
# invert
# 123
# inverted_44.png
# ../data_augmented_new/train/1/inverted_44.png
# invert
# 134
# inverted_59.png
# ../data_augmented_new/train/1/inverted_59.png
# rotate
# 158
# inverted_88.png
# ../data_augmented_new/train/1/inverted_88.png
# 63
# C_721_신-26.jpg
# ../data_augmented_new/train/1/C_721_신-26.jpg
# 237
# rotated_51.png
# ../data_augmented_new/train/1/rotated_51.png
# 240
# rotated_61.png
# ../data_augmented_new/train/1/rotated_61.png
# invert
# 99
# inverted_117.png
# ../data_augmented_new/train/1/inverted_117.png
# 103
# inverted_18.png
# ../data_augmented_new/train/1/inverted_18.png
# invert
# 67
# C_721_신-3.jpg
# ../data_augmented_new/train/1/C_721_신-3.jpg
# invert
# 228
# rotated_33.png
# ../data_augmented_new/train/1/rotated_33.png
# 124
# inverted_45.png
# ../data_augmented_new/train/1/inverted_45.png
# 90
# C_823_정-9.jpg
# ../data_augmented_new/train/1/C_823_정-9.jpg
# 38
# C_464_남-1.jpg
# ../data_augmented_new/train/1/C_464_남-1.jpg
# invert
# 166
# inverted_98.png
# ../data_augmented_new/train/1/inverted_98.png
# invert
# 160
# inverted_90.png
# ../data_augmented_new/train/1/inverted_90.png
# 83
# C_823_정-2.jpg
# ../data_augmented_new/train/1/C_823_정-2.jpg
# rotate
# 175
# noiseAdded_14.png
# ../data_augmented_new/train/1/noiseAdded_14.png
# invert
# 8
# abnormal (6).jpg
# ../data_augmented_new/train/1/abnormal (6).jpg
# rotate
# 162
# inverted_94.png
# ../data_augmented_new/train/1/inverted_94.png
# 60
# C_721_신-23.jpg
# ../data_augmented_new/train/1/C_721_신-23.jpg
# invert
# 140
# inverted_65.png
# ../data_augmented_new/train/1/inverted_65.png
# invert
# 239
# rotated_6.png
# ../data_augmented_new/train/1/rotated_6.png
# invert
# 115
# inverted_35.png
# ../data_augmented_new/train/1/inverted_35.png
# invert
# 157
# inverted_86.png
# ../data_augmented_new/train/1/inverted_86.png
# 54
# C_721_신-18.jpg
# ../data_augmented_new/train/1/C_721_신-18.jpg
# invert
# 157
# inverted_86.png
# ../data_augmented_new/train/1/inverted_86.png
# invert
# 250
# rotated_84.png
# ../data_augmented_new/train/1/rotated_84.png
# 140
# inverted_65.png
# ../data_augmented_new/train/1/inverted_65.png
# invert
# 113
# inverted_33.png
# ../data_augmented_new/train/1/inverted_33.png
# invert
# 250
# rotated_84.png
# ../data_augmented_new/train/1/rotated_84.png
# 200
# noiseAdded_72.png
# ../data_augmented_new/train/1/noiseAdded_72.png
# 96
# inverted_107.png
# ../data_augmented_new/train/1/inverted_107.png
# rotate
# 153
# inverted_81.png
# ../data_augmented_new/train/1/inverted_81.png
# invert
# 27
# C_253_다-7.jpg
# ../data_augmented_new/train/1/C_253_다-7.jpg
# rotate
# 171
# noiseAdded_113.png
# ../data_augmented_new/train/1/noiseAdded_113.png
# rotate
# 73
# C_721_신-9.jpg
# ../data_augmented_new/train/1/C_721_신-9.jpg
# invert
# 247
# rotated_8.png
# ../data_augmented_new/train/1/rotated_8.png
# rotate
# 204
# noiseAdded_80.png
# ../data_augmented_new/train/1/noiseAdded_80.png
# invert
# 197
# noiseAdded_6.png
# ../data_augmented_new/train/1/noiseAdded_6.png
# 44
# C_568_변-5.jpg
# ../data_augmented_new/train/1/C_568_변-5.jpg
# 103
# inverted_18.png
# ../data_augmented_new/train/1/inverted_18.png
# rotate
# 104
# inverted_2.png
# ../data_augmented_new/train/1/inverted_2.png
# invert
# 187
# noiseAdded_37.png
# ../data_augmented_new/train/1/noiseAdded_37.png
# 80
# C_782_백-4.jpg
# ../data_augmented_new/train/1/C_782_백-4.jpg
# rotate
# 245
# rotated_76.png
# ../data_augmented_new/train/1/rotated_76.png
# invert
# 59
# C_721_신-22.jpg
# ../data_augmented_new/train/1/C_721_신-22.jpg
# 54
# C_721_신-18.jpg
# ../data_augmented_new/train/1/C_721_신-18.jpg
# 192
# noiseAdded_50.png
# ../data_augmented_new/train/1/noiseAdded_50.png
# 213
# rotated_1.png
# ../data_augmented_new/train/1/rotated_1.png
# 142
# inverted_67.png
# ../data_augmented_new/train/1/inverted_67.png
# 201
# noiseAdded_74.png
# ../data_augmented_new/train/1/noiseAdded_74.png
# invert
# 224
# rotated_17.png
# ../data_augmented_new/train/1/rotated_17.png
# 1
# abnormal (10).jpg
# ../data_augmented_new/train/1/abnormal (10).jpg
# invert
# 60
# C_721_신-23.jpg
# ../data_augmented_new/train/1/C_721_신-23.jpg
# invert
# 45
# C_721_신-1.jpg
# ../data_augmented_new/train/1/C_721_신-1.jpg
# rotate
# 182
# noiseAdded_27.png
# ../data_augmented_new/train/1/noiseAdded_27.png
# 25
# C_253_다-5.jpg
# ../data_augmented_new/train/1/C_253_다-5.jpg
# invert
# 174
# noiseAdded_12.png
# ../data_augmented_new/train/1/noiseAdded_12.png
# 205
# noiseAdded_85.png
# ../data_augmented_new/train/1/noiseAdded_85.png
# 187
# noiseAdded_37.png
# ../data_augmented_new/train/1/noiseAdded_37.png
# 59
# C_721_신-22.jpg
# ../data_augmented_new/train/1/C_721_신-22.jpg
# 158
# inverted_88.png
# ../data_augmented_new/train/1/inverted_88.png
# 167
# inverted_99.png
# ../data_augmented_new/train/1/inverted_99.png
# 113
# inverted_33.png
# ../data_augmented_new/train/1/inverted_33.png
# invert
# 8
# abnormal (6).jpg
# ../data_augmented_new/train/1/abnormal (6).jpg
# 165
# inverted_97.png
# ../data_augmented_new/train/1/inverted_97.png
# invert
# 26
# C_253_다-6.jpg
# ../data_augmented_new/train/1/C_253_다-6.jpg
# 46
# C_721_신-10.jpg
# ../data_augmented_new/train/1/C_721_신-10.jpg
# rotate
# 30
# C_354_도-1.jpg
# ../data_augmented_new/train/1/C_354_도-1.jpg
# rotate
# 156
# inverted_85.png
# ../data_augmented_new/train/1/inverted_85.png
# 225
# rotated_18.png
# ../data_augmented_new/train/1/rotated_18.png
# invert
# 239
# rotated_6.png
# ../data_augmented_new/train/1/rotated_6.png
# 233
# rotated_45.png
# ../data_augmented_new/train/1/rotated_45.png
# invert
# 172
# noiseAdded_116.png
# ../data_augmented_new/train/1/noiseAdded_116.png
# rotate

# %%
data_transforms = {
    'train': transforms.Compose([T.Resize(256), T.CenterCrop(224), T.ToTensor()]),
    'test': transforms.Compose([T.Resize(256), T.CenterCrop(224), T.ToTensor()]),
#    'validation': transforms.Compose([T.Resize(256), T.CenterCrop(224), T.ToTensor()])
}

# %%
data_dir = '../data_augmented_new'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'test']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=8,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'test']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'test']}
class_names = image_datasets['train'].classes

device = torch.device("cuda")

# %%
import torchvision.models as models
resnet152 = models.resnet152(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to C:\Users\user/.cache\torch\hub\checkpoints\resnet152-b121ed2d.pth
#   0%|          | 0.00/230M [00:00<?, ?B/s]

# %%
model_cnn = resnet152.to(device)

#model_cnn = models.resnet18().to(device)
criterion = nn.CrossEntropyLoss()

# 모든 매개변수들이 최적화되었는지 관찰
optimizer = optim.SGD(model_cnn.parameters(), lr=0.1, momentum=0.9)
#lambda1 = lambda epoch:0.65**epoch
#schedular = optim.lr_scheduler.LambdaLR(optimizer, lr_lambda = lambda1)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.99)
#scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=1, eta_min=0.00001)

# %%
train_loader, test_loader= dataloaders['train'], dataloaders['test']
train_acc=[]
train_loss=[]


def train_model(model, criterion, optimizer):
    running_loss = 0 
    running_corrects = 0 

    model.train()  # 모델을 학습 모드로 설정
    for inputs, labels in train_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)        
        optimizer.zero_grad()
        
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        scheduler.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_acc = 100 * running_corrects.double() /  len(train_loader.dataset)

    print('train Loss: {:.4f} Acc: {:.4f}'.format(epoch_loss, epoch_acc))
    train_acc.append(epoch_acc)
    train_loss.append(epoch_loss)

# %%
test_acc=[]
test_loss=[]

def test_model(model):
 
    best_acc = 0.0
    model.eval()   

    running_loss = 0.0
    running_corrects = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)
 
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(test_loader.dataset)
    epoch_acc = 100 * running_corrects.double() / len(test_loader.dataset)


    if epoch_acc > best_acc:
        best_acc = epoch_acc

    print('test Loss: {:.4f} Acc: {:.4f}'.format(epoch_loss, epoch_acc))
    print()
    print('Best Test Acc: {:4f}'.format(best_acc))
    test_acc.append(epoch_acc)
    test_loss.append(epoch_loss)
 
 
    return best_acc

# %%
num_epochs =  100

for epoch in range(num_epochs):
    print('Epoch {}/{}'.format(epoch, num_epochs))
    print('-' * 10)

    train_model(model_cnn, criterion, optimizer)
    best_acc = test_model(model_cnn)
# Out:
# Epoch 0/100
# ----------
# train Loss: 4.4869 Acc: 54.7945
# test Loss: 512.2172 Acc: 56.2963
#
# Best Test Acc: 56.296296
# Epoch 1/100
# ----------
# train Loss: 0.7866 Acc: 65.0685
# test Loss: 0.6174 Acc: 77.7778
#
# Best Test Acc: 77.777778
# Epoch 2/100
# ----------
# train Loss: 1.4388 Acc: 59.2466
# test Loss: 2.5166 Acc: 39.2593
#
# Best Test Acc: 39.259259
# Epoch 3/100
# ----------
# train Loss: 0.7457 Acc: 66.7808
# test Loss: 1.0145 Acc: 59.2593
#
# Best Test Acc: 59.259259
# Epoch 4/100
# ----------
# train Loss: 0.7337 Acc: 71.9178
# test Loss: 3.2656 Acc: 66.6667
#
# Best Test Acc: 66.666667
# Epoch 5/100
# ----------
# train Loss: 0.7405 Acc: 70.5479
# test Loss: 0.5368 Acc: 66.6667
#
# Best Test Acc: 66.666667
# Epoch 6/100
# ----------
# train Loss: 0.5354 Acc: 76.3699
# test Loss: 0.5824 Acc: 73.3333
#
# Best Test Acc: 73.333333
# Epoch 7/100
# ----------
# train Loss: 0.6338 Acc: 71.2329
# test Loss: 1.5853 Acc: 68.8889
#
# Best Test Acc: 68.888889
# Epoch 8/100
# ----------
# train Loss: 0.5449 Acc: 75.6849
# test Loss: 0.5422 Acc: 62.9630
#
# Best Test Acc: 62.962963
# Epoch 9/100
# ----------
# train Loss: 0.5127 Acc: 78.4247
# test Loss: 0.4734 Acc: 75.5556
#
# Best Test Acc: 75.555556
# Epoch 10/100
# ----------
# train Loss: 0.4489 Acc: 80.8219
# test Loss: 1.3657 Acc: 63.7037
#
# Best Test Acc: 63.703704
# Epoch 11/100
# ----------
# train Loss: 0.4173 Acc: 81.5068
# test Loss: 0.4899 Acc: 67.4074
#
# Best Test Acc: 67.407407
# Epoch 12/100
# ----------
# train Loss: 0.4462 Acc: 79.1096
# test Loss: 0.3757 Acc: 79.2593
#
# Best Test Acc: 79.259259
# Epoch 13/100
# ----------
# train Loss: 0.4985 Acc: 80.8219
# test Loss: 0.5735 Acc: 64.4444
#
# Best Test Acc: 64.444444
# Epoch 14/100
# ----------
# train Loss: 0.4040 Acc: 82.1918
# test Loss: 0.8292 Acc: 63.7037
#
# Best Test Acc: 63.703704
# Epoch 15/100
# ----------
# train Loss: 0.4808 Acc: 79.7945
# test Loss: 1.1374 Acc: 63.7037
#
# Best Test Acc: 63.703704
# Epoch 16/100
# ----------
# train Loss: 0.4022 Acc: 82.8767
# test Loss: 0.5201 Acc: 61.4815
#
# Best Test Acc: 61.481481
# Epoch 17/100
# ----------
# train Loss: 0.4471 Acc: 80.4795
# test Loss: 0.5631 Acc: 61.4815
#
# Best Test Acc: 61.481481
# Epoch 18/100
# ----------
# train Loss: 0.4366 Acc: 80.8219
# test Loss: 0.5127 Acc: 66.6667
#
# Best Test Acc: 66.666667
# Epoch 19/100
# ----------
# train Loss: 0.4135 Acc: 81.8493
# test Loss: 0.5079 Acc: 64.4444
#
# Best Test Acc: 64.444444
# Epoch 20/100
# ----------
# train Loss: 0.4967 Acc: 75.3425
# test Loss: 0.5032 Acc: 62.2222
#
# Best Test Acc: 62.222222
# Epoch 21/100
# ----------
# train Loss: 0.3828 Acc: 82.1918
# test Loss: 0.4347 Acc: 76.2963
#
# Best Test Acc: 76.296296
# Epoch 22/100
# ----------
# train Loss: 0.4067 Acc: 82.5342
# test Loss: 0.3936 Acc: 73.3333
#
# Best Test Acc: 73.333333
# Epoch 23/100
# ----------
# train Loss: 0.3777 Acc: 84.9315
# test Loss: 0.3965 Acc: 69.6296
#
# Best Test Acc: 69.629630
# Epoch 24/100
# ----------
# train Loss: 0.4085 Acc: 82.1918
# test Loss: 0.3807 Acc: 85.9259
#
# Best Test Acc: 85.925926
# Epoch 25/100
# ----------
# train Loss: 0.3777 Acc: 81.5068
# test Loss: 0.4009 Acc: 78.5185
#
# Best Test Acc: 78.518519
# Epoch 26/100
# ----------
# train Loss: 0.3818 Acc: 82.8767
# test Loss: 0.4068 Acc: 87.4074
#
# Best Test Acc: 87.407407
# Epoch 27/100
# ----------
# train Loss: 0.3410 Acc: 85.2740
# test Loss: 0.4203 Acc: 69.6296
#
# Best Test Acc: 69.629630
# Epoch 28/100
# ----------
# train Loss: 0.3976 Acc: 82.8767
# test Loss: 0.4090 Acc: 85.1852
#
# Best Test Acc: 85.185185
# Epoch 29/100
# ----------
# train Loss: 0.3908 Acc: 83.5616
# test Loss: 0.4352 Acc: 70.3704
#
# Best Test Acc: 70.370370
# Epoch 30/100
# ----------
# train Loss: 0.3462 Acc: 84.2466
# test Loss: 0.4270 Acc: 77.0370
#
# Best Test Acc: 77.037037
# Epoch 31/100
# ----------
# train Loss: 0.3974 Acc: 84.9315
# test Loss: 0.3976 Acc: 83.7037
#
# Best Test Acc: 83.703704
# Epoch 32/100
# ----------
# train Loss: 0.3417 Acc: 83.5616
# test Loss: 0.3909 Acc: 80.0000
#
# Best Test Acc: 80.000000
# Epoch 33/100
# ----------
# train Loss: 0.3298 Acc: 83.5616
# test Loss: 0.3748 Acc: 85.9259
#
# Best Test Acc: 85.925926
# Epoch 34/100
# ----------
# train Loss: 0.3247 Acc: 85.9589
# test Loss: 0.4290 Acc: 66.6667
#
# Best Test Acc: 66.666667
# Epoch 35/100
# ----------
# train Loss: 0.3064 Acc: 85.9589
# test Loss: 0.4163 Acc: 68.1481
#
# Best Test Acc: 68.148148
# Epoch 36/100
# ----------
# train Loss: 0.2836 Acc: 89.7260
# test Loss: 0.3691 Acc: 88.8889
#
# Best Test Acc: 88.888889
# Epoch 37/100
# ----------
# train Loss: 0.3095 Acc: 86.3014
# test Loss: 0.4042 Acc: 71.1111
#
# Best Test Acc: 71.111111
# Epoch 38/100
# ----------
# train Loss: 0.3155 Acc: 86.6438
# test Loss: 0.4044 Acc: 78.5185
#
# Best Test Acc: 78.518519
# Epoch 39/100
# ----------
# train Loss: 0.3172 Acc: 87.6712
# test Loss: 0.3828 Acc: 81.4815
#
# Best Test Acc: 81.481481
# Epoch 40/100
# ----------
# train Loss: 0.3182 Acc: 84.9315
# test Loss: 0.4052 Acc: 76.2963
#
# Best Test Acc: 76.296296
# Epoch 41/100
# ----------
# train Loss: 0.3494 Acc: 85.9589
# test Loss: 0.4044 Acc: 69.6296
#
# Best Test Acc: 69.629630
# Epoch 42/100
# ----------
# train Loss: 0.2962 Acc: 85.2740
# test Loss: 0.4043 Acc: 68.8889
#
# Best Test Acc: 68.888889
# Epoch 43/100
# ----------
# train Loss: 0.3130 Acc: 86.9863
# test Loss: 0.4019 Acc: 71.1111
#
# Best Test Acc: 71.111111
# Epoch 44/100
# ----------
# train Loss: 0.2730 Acc: 90.0685
# test Loss: 0.3875 Acc: 80.7407
#
# Best Test Acc: 80.740741
# Epoch 45/100
# ----------
# train Loss: 0.2946 Acc: 87.6712
# test Loss: 0.3931 Acc: 74.8148
#
# Best Test Acc: 74.814815
# Epoch 46/100
# ----------
# train Loss: 0.2811 Acc: 89.0411
# test Loss: 0.3963 Acc: 82.9630
#
# Best Test Acc: 82.962963
# Epoch 47/100
# ----------
# train Loss: 0.3143 Acc: 86.9863
# test Loss: 0.3982 Acc: 82.9630
#
# Best Test Acc: 82.962963
# Epoch 48/100
# ----------
# train Loss: 0.3009 Acc: 84.2466
# test Loss: 0.4004 Acc: 74.8148
#
# Best Test Acc: 74.814815
# Epoch 49/100
# ----------
# train Loss: 0.3355 Acc: 87.6712
# test Loss: 0.3967 Acc: 71.8519
#
# Best Test Acc: 71.851852
# Epoch 50/100
# ----------
# train Loss: 0.2825 Acc: 87.6712
# test Loss: 0.4131 Acc: 69.6296
#
# Best Test Acc: 69.629630
# Epoch 51/100
# ----------
# train Loss: 0.2914 Acc: 85.6164
# test Loss: 0.4014 Acc: 71.1111
#
# Best Test Acc: 71.111111
# Epoch 52/100
# ----------
# train Loss: 0.2735 Acc: 86.6438
# test Loss: 0.3871 Acc: 83.7037
#
# Best Test Acc: 83.703704
# Epoch 53/100
# ----------
# train Loss: 0.2963 Acc: 85.6164
# test Loss: 0.3879 Acc: 80.0000
#
# Best Test Acc: 80.000000
# Epoch 54/100
# ----------
# train Loss: 0.2924 Acc: 89.0411
# test Loss: 0.3950 Acc: 79.2593
#
# Best Test Acc: 79.259259
# Epoch 55/100
# ----------
# train Loss: 0.3182 Acc: 85.6164
# test Loss: 0.3912 Acc: 78.5185
#
# Best Test Acc: 78.518519
# Epoch 56/100
# ----------
# train Loss: 0.2850 Acc: 90.0685
# test Loss: 0.3981 Acc: 78.5185
#
# Best Test Acc: 78.518519
# Epoch 57/100
# ----------
# train Loss: 0.2963 Acc: 85.9589
# test Loss: 0.3864 Acc: 76.2963
#
# Best Test Acc: 76.296296
# Epoch 58/100
# ----------
# train Loss: 0.3352 Acc: 85.9589
# test Loss: 0.3909 Acc: 73.3333
#
# Best Test Acc: 73.333333
# Epoch 59/100
# ----------
# train Loss: 0.3093 Acc: 88.0137
# test Loss: 0.4049 Acc: 77.0370
#
# Best Test Acc: 77.037037
# Epoch 60/100
# ----------
# train Loss: 0.2839 Acc: 88.0137
# test Loss: 0.3892 Acc: 79.2593
#
# Best Test Acc: 79.259259
# Epoch 61/100
# ----------
# train Loss: 0.2680 Acc: 86.9863
# test Loss: 0.3887 Acc: 79.2593
#
# Best Test Acc: 79.259259
# Epoch 62/100
# ----------
# train Loss: 0.2533 Acc: 88.3562
# test Loss: 0.4126 Acc: 69.6296
#
# Best Test Acc: 69.629630
# Epoch 63/100
# ----------
# train Loss: 0.3029 Acc: 89.3836
# test Loss: 0.3897 Acc: 73.3333
#
# Best Test Acc: 73.333333
# Epoch 64/100
# ----------
# train Loss: 0.2856 Acc: 86.9863
# test Loss: 0.3875 Acc: 75.5556
#
# Best Test Acc: 75.555556
# Epoch 65/100
# ----------
# train Loss: 0.3163 Acc: 85.2740
# test Loss: 0.3887 Acc: 75.5556
#
# Best Test Acc: 75.555556
# Epoch 66/100
# ----------
# train Loss: 0.2493 Acc: 90.0685
# test Loss: 0.4017 Acc: 75.5556
#
# Best Test Acc: 75.555556
# Epoch 67/100
# ----------
# train Loss: 0.3445 Acc: 84.5890
# test Loss: 0.3866 Acc: 80.0000
#
# Best Test Acc: 80.000000
# Epoch 68/100
# ----------
# train Loss: 0.3422 Acc: 86.6438
# test Loss: 0.4037 Acc: 83.7037
#
# Best Test Acc: 83.703704
# Epoch 69/100
# ----------
# train Loss: 0.3276 Acc: 85.2740
# test Loss: 0.4115 Acc: 80.7407
#
# Best Test Acc: 80.740741
# Epoch 70/100
# ----------
# train Loss: 0.2802 Acc: 87.6712
# test Loss: 0.3895 Acc: 85.1852
#
# Best Test Acc: 85.185185
# Epoch 71/100
# ----------
# train Loss: 0.2635 Acc: 88.6986
# test Loss: 0.4329 Acc: 82.2222
#
# Best Test Acc: 82.222222
# Epoch 72/100
# ----------
# train Loss: 0.2562 Acc: 88.3562
# test Loss: 0.3896 Acc: 80.0000
#
# Best Test Acc: 80.000000
# Epoch 73/100
# ----------
# train Loss: 0.2908 Acc: 87.6712
# test Loss: 0.3845 Acc: 79.2593
#
# Best Test Acc: 79.259259
# Epoch 74/100
# ----------
# train Loss: 0.2604 Acc: 89.0411
# test Loss: 0.3920 Acc: 81.4815
#
# Best Test Acc: 81.481481
# Epoch 75/100
# ----------
# train Loss: 0.2959 Acc: 86.6438
# test Loss: 0.3859 Acc: 83.7037
#
# Best Test Acc: 83.703704
# Epoch 76/100
# ----------
# train Loss: 0.3371 Acc: 87.3288
# test Loss: 0.3996 Acc: 80.7407
#
# Best Test Acc: 80.740741
# Epoch 77/100
# ----------
# train Loss: 0.2908 Acc: 87.6712
# test Loss: 0.3935 Acc: 81.4815
#
# Best Test Acc: 81.481481
# Epoch 78/100
# ----------
# train Loss: 0.2997 Acc: 88.3562
# test Loss: 0.3934 Acc: 80.0000
#
# Best Test Acc: 80.000000
# Epoch 79/100
# ----------
# train Loss: 0.3098 Acc: 87.6712
# test Loss: 0.3934 Acc: 76.2963
#
# Best Test Acc: 76.296296
# Epoch 80/100
# ----------
# train Loss: 0.3050 Acc: 86.3014
# test Loss: 0.3883 Acc: 78.5185
#
# Best Test Acc: 78.518519
# Epoch 81/100
# ----------
# train Loss: 0.2584 Acc: 87.6712
# test Loss: 0.3962 Acc: 81.4815
#
# Best Test Acc: 81.481481
# Epoch 82/100
# ----------
# train Loss: 0.2913 Acc: 87.3288
# test Loss: 0.4065 Acc: 80.0000
#
# Best Test Acc: 80.000000
# Epoch 83/100
# ----------
# train Loss: 0.3091 Acc: 84.5890
# test Loss: 0.3878 Acc: 81.4815
#
# Best Test Acc: 81.481481
# Epoch 84/100
# ----------
# train Loss: 0.2631 Acc: 88.0137
# test Loss: 0.4031 Acc: 80.0000
#
# Best Test Acc: 80.000000
# Epoch 85/100
# ----------
# train Loss: 0.2518 Acc: 88.3562
# test Loss: 0.4432 Acc: 84.4444
#
# Best Test Acc: 84.444444
# Epoch 86/100
# ----------
# train Loss: 0.2328 Acc: 88.6986
# test Loss: 0.3891 Acc: 82.9630
#
# Best Test Acc: 82.962963
# Epoch 87/100
# ----------
# train Loss: 0.2764 Acc: 87.6712
# test Loss: 0.3797 Acc: 82.9630
#
# Best Test Acc: 82.962963
# Epoch 88/100
# ----------
# train Loss: 0.2777 Acc: 89.0411
# test Loss: 0.3966 Acc: 80.7407
#
# Best Test Acc: 80.740741
# Epoch 89/100
# ----------
# train Loss: 0.3020 Acc: 88.3562
# test Loss: 0.4257 Acc: 85.1852
#
# Best Test Acc: 85.185185
# Epoch 90/100
# ----------
# train Loss: 0.2706 Acc: 87.6712
# test Loss: 0.3867 Acc: 82.2222
#
# Best Test Acc: 82.222222
# Epoch 91/100
# ----------
# train Loss: 0.2892 Acc: 89.0411
# test Loss: 0.3952 Acc: 83.7037
#
# Best Test Acc: 83.703704
# Epoch 92/100
# ----------
# train Loss: 0.3228 Acc: 84.5890
# test Loss: 0.4527 Acc: 85.9259
#
# Best Test Acc: 85.925926
# Epoch 93/100
# ----------
# train Loss: 0.2720 Acc: 88.6986
# test Loss: 0.3857 Acc: 82.9630
#
# Best Test Acc: 82.962963
# Epoch 94/100
# ----------
# train Loss: 0.2720 Acc: 88.6986
# test Loss: 0.3878 Acc: 83.7037
#
# Best Test Acc: 83.703704
# Epoch 95/100
# ----------
# train Loss: 0.2700 Acc: 88.3562
# test Loss: 0.3958 Acc: 81.4815
#
# Best Test Acc: 81.481481
# Epoch 96/100
# ----------
# train Loss: 0.3131 Acc: 86.3014
# test Loss: 0.3882 Acc: 80.7407
#
# Best Test Acc: 80.740741
# Epoch 97/100
# ----------
# train Loss: 0.2944 Acc: 86.9863
# test Loss: 0.3927 Acc: 80.0000
#
# Best Test Acc: 80.000000
# Epoch 98/100
# ----------
# train Loss: 0.3194 Acc: 87.6712
# test Loss: 0.3919 Acc: 80.0000
#
# Best Test Acc: 80.000000
# Epoch 99/100
# ----------
# train Loss: 0.2797 Acc: 87.3288
# test Loss: 0.3802 Acc: 78.5185
#
# Best Test Acc: 78.518519
