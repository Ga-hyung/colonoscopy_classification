# %%
# !pip install torchsummary
# Out:
# Collecting torchsummary
#   Downloading torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: torchsummary
# Successfully installed torchsummary-1.5.1

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
import torch.nn.functional as F

from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import cv2
import torchsummary

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 이미지 자르기

# %%
path = '../data_new/'
image_list = os.listdir(path)

tmp = []
for image in image_list:
    temp = cv2.imread(path+image)
    tmp.append(temp.shape[:2])
#     print(image, temp.shape)

# %%
for image in image_list:
    temp = cv2.imread(path+image)
    img_trimed = temp[50::, 400::]
    cv2.imwrite(image+'_trimmed.jpg', img_trimed)

# %% [markdown]
# ## 학습 돌리기

# %%
data_transforms = {
    'train': transforms.Compose([
#        transforms.CenterCrop(1000),
        transforms.Resize((122, 122)),
#        transforms.Grayscale(),
        #transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
#        transforms.Normalize([0.5], [0.5])
    ]),
    'test': transforms.Compose([
#        transforms.CenterCrop(800),
        transforms.Resize((122, 122)),
        transforms.ToTensor(),
#        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
    ]),
    
}

# %%
# 학습을 위해 데이터 증가(augmentation) 및 일반화(normalization)
# 검증을 위한 일반화
data_dir = '../data_augmented_new'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'test']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'test']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'test']}
class_names = image_datasets['train'].classes

device = torch.device("cpu")

# %%
class_names
# Out:
# ['0', '1']

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.5])
    std = np.array([0.5])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
   
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # 갱신이 될 때까지 잠시 기다립니다.


# 학습 데이터의 배치를 얻습니다.
inputs, classes = next(iter(dataloaders['train']))

# 배치로부터 격자 형태의 이미지를 만듭니다.
out = torchvision.utils.make_grid(inputs)

plt.figure(figsize=(15,15))
imshow(out, title=[class_names[x] for x in classes])

# %%
class SimpleCNN(nn.Module):
    def __init__(self, output_dim=12):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 3, 5, padding=2, stride=2)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(3, 6, 5, padding=2, stride=2)

        self.fc1 = nn.Linear(6*7*7, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 2)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
#        print(x.shape)
        x = self.pool(F.relu(self.conv2(x)))
#        print(x.shape)
        x = x.view(-1, 6 * 7 * 7)

        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
model_cnn = SimpleCNN().to(device)

#model_cnn = models.resnet18().to(device)
criterion = nn.CrossEntropyLoss()

# 모든 매개변수들이 최적화되었는지 관찰
optimizer = optim.Adam(model_cnn.parameters())

# %%
train_loader, test_loader = dataloaders['train'], dataloaders['test']
#import pdb

def train_model(model, criterion, optimizer):
    running_loss = 0 
    running_corrects = 0 

    model.train()  # 모델을 학습 모드로 설정
    for inputs, labels in train_loader:
#        print(inputs.size(), labels.size())
        inputs = inputs.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_acc = 100 * running_corrects.double() /  len(train_loader.dataset)

    print('train Loss: {:.4f} Acc: {:.4f}'.format(epoch_loss, epoch_acc))

# %%
def test_model(model):
 
    best_acc = 0.0
    model.eval()   

    running_loss = 0.0
    running_corrects = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)
 
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(test_loader.dataset)
    epoch_acc = 100 * running_corrects.double() / len(test_loader.dataset)


    if epoch_acc > best_acc:
        best_acc = epoch_acc

    print('test Loss: {:.4f} Acc: {:.4f}'.format(epoch_loss, epoch_acc))
    print()
    print('Best val Acc: {:4f}'.format(best_acc))
 
    return best_acc

# %%
num_epochs = 50

for epoch in range(num_epochs):
    print('Epoch {}/{}'.format(epoch, num_epochs - 1))
    print('-' * 10)

    train_model(model_cnn, criterion, optimizer)
    best_acc = test_model(model_cnn)
# Out:
# Epoch 0/49
# ----------
# train Loss: 0.6864 Acc: 55.4622
# test Loss: 0.6921 Acc: 60.0000
#
# Best val Acc: 60.000000
# Epoch 1/49
# ----------
# train Loss: 0.6035 Acc: 67.6471
# test Loss: 1.0580 Acc: 26.6667
#
# Best val Acc: 26.666667
# Epoch 2/49
# ----------
# train Loss: 0.4656 Acc: 76.4706
# test Loss: 1.4029 Acc: 30.0000
#
# Best val Acc: 30.000000
# Epoch 3/49
# ----------
# train Loss: 0.4052 Acc: 81.0924
# test Loss: 2.7043 Acc: 36.6667
#
# Best val Acc: 36.666667
# Epoch 4/49
# ----------
# train Loss: 0.2599 Acc: 89.0756
# test Loss: 3.4824 Acc: 30.0000
#
# Best val Acc: 30.000000
# Epoch 5/49
# ----------
# train Loss: 0.2025 Acc: 92.0168
# test Loss: 3.9098 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 6/49
# ----------
# train Loss: 0.1339 Acc: 95.7983
# test Loss: 3.9133 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 7/49
# ----------
# train Loss: 0.0837 Acc: 97.4790
# test Loss: 5.8071 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 8/49
# ----------
# train Loss: 0.0956 Acc: 95.7983
# test Loss: 4.7994 Acc: 26.6667
#
# Best val Acc: 26.666667
# Epoch 9/49
# ----------
# train Loss: 0.0735 Acc: 97.4790
# test Loss: 6.8898 Acc: 26.6667
#
# Best val Acc: 26.666667
# Epoch 10/49
# ----------
# train Loss: 0.0334 Acc: 98.7395
# test Loss: 8.6153 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 11/49
# ----------
# train Loss: 0.1837 Acc: 92.8571
# test Loss: 6.2058 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 12/49
# ----------
# train Loss: 0.0595 Acc: 97.4790
# test Loss: 6.4851 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 13/49
# ----------
# train Loss: 0.0188 Acc: 100.0000
# test Loss: 7.3845 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 14/49
# ----------
# train Loss: 0.0099 Acc: 100.0000
# test Loss: 7.9015 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 15/49
# ----------
# train Loss: 0.0030 Acc: 100.0000
# test Loss: 8.4151 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 16/49
# ----------
# train Loss: 0.0018 Acc: 100.0000
# test Loss: 8.5752 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 17/49
# ----------
# train Loss: 0.0016 Acc: 100.0000
# test Loss: 8.3822 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 18/49
# ----------
# train Loss: 0.0010 Acc: 100.0000
# test Loss: 8.5825 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 19/49
# ----------
# train Loss: 0.0008 Acc: 100.0000
# test Loss: 8.9467 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 20/49
# ----------
# train Loss: 0.0006 Acc: 100.0000
# test Loss: 9.0161 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 21/49
# ----------
# train Loss: 0.0005 Acc: 100.0000
# test Loss: 9.2026 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 22/49
# ----------
# train Loss: 0.0005 Acc: 100.0000
# test Loss: 9.3151 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 23/49
# ----------
# train Loss: 0.0004 Acc: 100.0000
# test Loss: 9.4387 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 24/49
# ----------
# train Loss: 0.0004 Acc: 100.0000
# test Loss: 9.4850 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 25/49
# ----------
# train Loss: 0.0003 Acc: 100.0000
# test Loss: 9.7546 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 26/49
# ----------
# train Loss: 0.0003 Acc: 100.0000
# test Loss: 9.9160 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 27/49
# ----------
# train Loss: 0.0002 Acc: 100.0000
# test Loss: 9.9360 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 28/49
# ----------
# train Loss: 0.0002 Acc: 100.0000
# test Loss: 9.9786 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 29/49
# ----------
# train Loss: 0.0002 Acc: 100.0000
# test Loss: 10.0780 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 30/49
# ----------
# train Loss: 0.0002 Acc: 100.0000
# test Loss: 10.2857 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 31/49
# ----------
# train Loss: 0.0002 Acc: 100.0000
# test Loss: 10.2943 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 32/49
# ----------
# train Loss: 0.0001 Acc: 100.0000
# test Loss: 10.4073 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 33/49
# ----------
# train Loss: 0.0001 Acc: 100.0000
# test Loss: 10.5173 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 34/49
# ----------
# train Loss: 0.0001 Acc: 100.0000
# test Loss: 10.5813 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 35/49
# ----------
# train Loss: 0.0001 Acc: 100.0000
# test Loss: 10.6142 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 36/49
# ----------
# train Loss: 0.0001 Acc: 100.0000
# test Loss: 10.7634 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 37/49
# ----------
# train Loss: 0.0001 Acc: 100.0000
# test Loss: 10.8322 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 38/49
# ----------
# train Loss: 0.0001 Acc: 100.0000
# test Loss: 10.9093 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 39/49
# ----------
# train Loss: 0.0001 Acc: 100.0000
# test Loss: 11.0097 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 40/49
# ----------
# train Loss: 0.0001 Acc: 100.0000
# test Loss: 11.0707 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 41/49
# ----------
# train Loss: 0.0001 Acc: 100.0000
# test Loss: 11.1461 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 42/49
# ----------
# train Loss: 0.0001 Acc: 100.0000
# test Loss: 11.2641 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 43/49
# ----------
# train Loss: 0.0001 Acc: 100.0000
# test Loss: 11.2828 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 44/49
# ----------
# train Loss: 0.0001 Acc: 100.0000
# test Loss: 11.3009 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 45/49
# ----------
# train Loss: 0.0001 Acc: 100.0000
# test Loss: 11.4839 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 46/49
# ----------
# train Loss: 0.0001 Acc: 100.0000
# test Loss: 11.5443 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 47/49
# ----------
# train Loss: 0.0000 Acc: 100.0000
# test Loss: 11.5849 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 48/49
# ----------
# train Loss: 0.0000 Acc: 100.0000
# test Loss: 11.6077 Acc: 33.3333
#
# Best val Acc: 33.333333
# Epoch 49/49
# ----------
# train Loss: 0.0000 Acc: 100.0000
# test Loss: 11.6953 Acc: 33.3333
#
# Best val Acc: 33.333333

# %%
def visualize_model1(model, num_images=12):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure(figsize=(8,8))

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')

                ax.set_title('predicted: {} , labels : {}'.format(class_names[preds[j]] , class_names[labels[j]]))
                #imshow(inputs.cpu().data[j])
                ##
                out = torchvision.utils.make_grid(inputs.data[j])
                fig = plt.figure(figsize=(12,12))
                imshow(out)
                fig.savefig('result_'+str(images_so_far)+'_.png')
                ##
                
                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
visualize_model1(model_cnn)
